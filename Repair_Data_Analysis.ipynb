# %%
import pandas as pd

# %%
df = pd.read_csv('OpenRepairData_aggregated.csv')

# %%
# index by country = GBR
df_gbr = df[df['country'] == 'GBR']
df_gbr.head()
# Out:
#                  id              data_provider country  \
# 32724  rcint_146320  Repair Café International     GBR
# 32725  rcint_146315  Repair Café International     GBR
# 32726  rcint_146314  Repair Café International     GBR
# 32727  rcint_146313  Repair Café International     GBR
# 32728  rcint_146309  Repair Café International     GBR
#
#                              partner_product_category    product_category  \
# 32724       Household appliances electric ~ Hot plate  Small kitchen item
# 32725  Household appliances electric ~ Food processor      Food processor
# 32726                   Clocks / alarm clocks ~ Clock         Watch/clock
# 32727      Household appliances electric ~ Table lamp                Lamp
# 32728           Display and sound equipment ~ Speaker     Hi-Fi separates
#
#        product_category_id    brand  year_of_manufacture  product_age  \
# 32724                   29  Unknown                  NaN          NaN
# ...

# %%
# sort by most common product categories
df_gbr['product_category'].value_counts().head(10)
# Out:
# product_category
# Lamp                     7224
# Vacuum                   6667
# Small home electrical    6490
# Power tool               5315
# Laptop                   5164
# Portable radio           4829
# Hi-Fi separates          4100
# Food processor           3553
# Watch/clock              3476
# Toaster                  2815
# Name: count, dtype: int64

# %%
# sort by most common brand
df_gbr['brand'].value_counts().head(10)
# Out:
# brand
# Unknown          32744
# Dyson             1768
# Sony              1437
# HP                1358
# Bosch             1170
# Apple             1127
# Kenwood           1074
# Roberts           1014
# Russell Hobbs      804
# Samsung            786
# Name: count, dtype: int64

# %%
# sort by repair_barrier_if_end_of_life
df_gbr['repair_barrier_if_end_of_life'].value_counts().head(10)
# Out:
# repair_barrier_if_end_of_life
# Spare parts not available           2391
# Item too worn out                   1998
# No way to open product              1777
# Spare parts too expensive           1306
# Repair information not available    1007
# Lack of equipment                    336
# Name: count, dtype: int64
